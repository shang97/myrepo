# %%
import lr_utils 
# 如果修改了 py 文件，需要把这个 ipnb 关闭，重新加载一下才行
import L_layers_Logistic

# %matplotlib inline

# %%
train_set_x_orig, train_set_y, test_set_x_orig, test_set_y, classes = lr_utils.load_dataset()
train_set_x_orig.shape,  test_set_x_orig.shape
# Out:
# ((209, 64, 64, 3), (50, 64, 64, 3))

# %%
train_x_flatten = train_set_x_orig.reshape(train_set_x_orig.shape[0], -1).T 
test_x_flatten = test_set_x_orig.reshape(test_set_x_orig.shape[0], -1).T

# 最大像素值 255（0-255）
train_x = train_x_flatten / 255
train_y = train_set_y
test_x = test_x_flatten / 255
test_y = test_set_y

# %%
# %%time
# 两层的网络
# （n_x, n_h, n_y）=（12288, 7, 1）
layers_dims = train_x.shape[0], 7, 1
parameters1 = L_layers_Logistic.L_layers_model(train_x, train_y, layers_dims, num_iterations=3000, print_cost=True, isPlot=True)
# Out:
# 第 0 次迭代，成本值为： 0.672879355630254
# 第 500 次迭代，成本值为： 0.26482154965710536
# 第 1000 次迭代，成本值为： 0.07294746161232646
# 第 1500 次迭代，成本值为： 0.03149533255722909
# 第 2000 次迭代，成本值为： 0.019482008318370127
# 第 2500 次迭代，成本值为： 0.014143932515018444
# 第 3000 次迭代，成本值为： 0.011190602678598614
# Wall time: 51.3 s

# %%
# %%time
# 三层的网络
layers_dims = (train_x.shape[0], 15, 7, 1)
parameters2 = L_layers_Logistic.L_layers_model(train_x, train_y, layers_dims, num_iterations=3000, print_cost=True, isPlot=True)
# Out:
# 第 0 次迭代，成本值为： 0.6865915690176918
# 第 500 次迭代，成本值为： 0.3754614847695666
# 第 1000 次迭代，成本值为： 0.37203471377029895
# 第 1500 次迭代，成本值为： 0.11582363643924233
# 第 2000 次迭代，成本值为： 0.023252361857717847
# 第 2500 次迭代，成本值为： 0.007444690337662079
# 第 3000 次迭代，成本值为： 0.00439776992737365
# Wall time: 1min 21s
